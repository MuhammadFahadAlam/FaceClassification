# %% [markdown]
# # Face Recognition

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from skimage import io, transform
import os

# %matplotlib inline

# %% [markdown]
# ## Helper Functions

# %% [markdown]
# ### Splitting Data

# %%
def split_data(path = 'FaceDataset'):
    subfolders = [f.path for f in os.scandir(path) if f.is_dir()]
    sorted(subfolders)
    train = []
    test = []
    for subfolder in subfolders:
        dirFiles = os.listdir(subfolder)
        sorted(dirFiles)
        subImages = []
        for img in dirFiles:
            if os.path.splitext(img)[1] == '.pgm':
                subImages.append(subfolder+'\\'+img)
        subTrain = subImages[ : len(subImages)//2]
        train.extend(subTrain)
        subTest = subImages[len(subImages)//2 : ]
        test.extend(subTest)
    return train, test

# %% [markdown]
# ### Basic Functions

# %%
def openImage(path):
    return io.imread(path)

def displayImage(image_arr):
    plt.imshow(image_arr)
    
def downscale(image_arr):
    return transform.resize(image_arr, (image_arr.shape[0]//2,image_arr.shape[1]//2))

def toVector(image_arr):
    return image_arr.reshape(-1,1)

# %% [markdown]
# ### Class Model Making Function

# %%
def allClassModels(dirGroup):
    groups = dirGroup.groups.keys()
    models = []
    for group_name in groups:
        group = dirGroup.get_group(group_name)
        images = group["Images"]
        vectorImages = []
        for img in images:
            vectorImages.append(toVector(downscale(openImage(img))))
        model = np.hstack(vectorImages)
        models.append(model)
    return np.array(models)

# %% [markdown]
# ## Algorithm

# %%
def B_hat(key_to_class, train_df):
    Bees = []
    for i in range(train_df.shape[0]):
        image_url = train_df["Images"][i]
        y = toVector(downscale(openImage(image_url)))
        X = key_to_class[ train_df["Dir"][i] ]
        Xt = np.transpose(X)
        inv = np.linalg.inv(np.dot(Xt,X)) 
        B = np.dot(inv,np.dot(Xt,y))
        Bees.append(B)
    train_df["Bees"] = Bees

# %%
def distance(key_to_class, train_df, test):
    B_hat(key_to_class, train_df)
    test_df = train_df.copy()
    y = toVector(downscale(openImage(test)))
    dist_list = []
    for i in range(test_df.shape[0]):
        X = key_to_class[test_df["Dir"][i]]
        y_hat = np.dot(X, test_df["Bees"][i])
        dist = np.linalg.norm(y-y_hat)
        dist_list.append(dist)
    test_df["Distance"] = dist_list
    return test_df

# %%
def predict(key_to_class, train_df, test):
    test_df = distance(key_to_class, train_df, test)
    minDist = test_df["Distance"].idxmin()
    return test_df.loc[minDist]["Dir"]

# %% [markdown]
# ## Accuracy

# %%
def getAccuracy(key_to_class, train_df, testing_df):
    all_min_dist = []
    predictions = []
    for i in range(testing_df.shape[0]):
        test_df = distance(key_to_class, train_df, testing_df["Images"][i])
        minDist = test_df["Distance"].idxmin()
        all_min_dist.append(test_df.loc[minDist]['Distance'])
        pred = test_df.loc[minDist]['Dir']
        predictions.append(pred)
    testing_df['Prediction'] = predictions
    testing_df['L2-Norm'] = all_min_dist
    testing_df['Right'] = testing_df['Dir'] == testing_df['Prediction']
    print("Accuracy = ",testing_df['Right'].value_counts()[True]/2)
    return testing_df

# %% [markdown]
# ## Real Implementation

# %% [markdown]
# Spliting Data into Train and Test Data

# %%
train, test = split_data()

# %% [markdown]
# Making DataFrames of Train and Test Data to make it easy to manage

# %%
train_df = pd.DataFrame(train, columns=['Images'])
train_df["Dir"] = train_df["Images"].str.split("\\").str.get(1)

testing_df = pd.DataFrame(test, columns=['Images'])
testing_df["Dir"] = testing_df["Images"].str.split("\\").str.get(1)

# %% [markdown]
# Grouping by classes

# %%
dirGroup = train_df.groupby('Dir')
keys = dirGroup.groups.keys()

# %% [markdown]
# Making Predictor for each class

# %%
X1, X10, X11, X12, X13, X14, X15, X16, X17, X18, X19, X2, X20, X21, X22, X23, X24, X25, X26, X27, X28, X29, X3, X30, X31, X32, X33, X34, X35, X36, X37, X38, X9, X4, X40, X5, X6, X7, X8, X9 = allClassModels(dirGroup)
classes = [X1, X10, X11, X12, X13, X14, X15, X16, X17, X18, X19, X2, X20, X21, X22, X23, X24, X25, X26, X27, X28, X29, X3, X30, X31, X32, X33, X34, X35, X36, X37, X38, X9, X4, X40, X5, X6, X7, X8, X9]

# %% [markdown]
# Making a dictionary mapping the key to the predictor

# %%
key_to_class = dict(zip(keys, classes))

# %% [markdown]
# Predicting the class of the Image

# %%
predict(key_to_class, train_df, "FaceDataset\\s1\\1.pgm")
# Out:
# 's1'

# %% [markdown]
# Accuracy of our Model

# %%
pd.set_option("display.max_rows", None)

# %%
getAccuracy(key_to_class, train_df, testing_df)
# Out:
# Accuracy =  91.5
#                     Images  Dir Prediction   L2-Norm  Right
# 0     FaceDataset\s1\5.pgm   s1         s1  7.012997   True
# 1     FaceDataset\s1\6.pgm   s1         s1  6.488480   True
# 2     FaceDataset\s1\7.pgm   s1         s1  6.560869   True
# 3     FaceDataset\s1\8.pgm   s1         s1  7.321900   True
# 4     FaceDataset\s1\9.pgm   s1         s1  8.011391   True
# 5    FaceDataset\s10\5.pgm  s10        s10  6.364379   True
# 6    FaceDataset\s10\6.pgm  s10        s10  6.403414   True
# 7    FaceDataset\s10\7.pgm  s10        s10  5.608173   True
# 8    FaceDataset\s10\8.pgm  s10        s10  4.524284   True
# 9    FaceDataset\s10\9.pgm  s10        s38  7.915857  False
# 10   FaceDataset\s11\5.pgm  s11        s11  3.909200   True
# 11   FaceDataset\s11\6.pgm  s11        s11  5.374685   True
# 12   FaceDataset\s11\7.pgm  s11        s11  5.184762   True
# 13   FaceDataset\s11\8.pgm  s11        s11  8.047358   True
# 14   FaceDataset\s11\9.pgm  s11        s11  6.031063   True
# 15   FaceDataset\s12\5.pgm  s12        s12  4.519150   True
# 16   FaceDataset\s12\6.pgm  s12        s12  5.600315   True
# 17   FaceDataset\s12\7.pgm  s12        s12  4.052516   True
# 18   FaceDataset\s12\8.pgm  s12        s12  4.779553   True
# 19   FaceDataset\s12\9.pgm  s12        s12  3.792010   True
# 20   FaceDataset\s13\5.pgm  s13        s13  2.782991   True
# 21   FaceDataset\s13\6.pgm  s13        s13  5.889569   True
# 22   FaceDataset\s13\7.pgm  s13        s13  5.375967   True
# 23   FaceDataset\s13\8.pgm  s13        s13  5.073459   True
# 24   FaceDataset\s13\9.pgm  s13        s13  4.820289   True
# 25   FaceDataset\s14\5.pgm  s14        s14  4.063110   True
# 26   FaceDataset\s14\6.pgm  s14        s14  6.696402   True
# 27   FaceDataset\s14\7.pgm  s14        s14  6.822637   True
# 28   FaceDataset\s14\8.pgm  s14        s14  6.829382   True
# 29   FaceDataset\s14\9.pgm  s14        s14  6.589255   True
# 30   FaceDataset\s15\5.pgm  s15        s15  3.424851   True
# 31   FaceDataset\s15\6.pgm  s15        s15  3.458390   True
# 32   FaceDataset\s15\7.pgm  s15        s15  3.722323   True
# 33   FaceDataset\s15\8.pgm  s15        s15  5.700527   True
# 34   FaceDataset\s15\9.pgm  s15        s15  4.654616   True
# 35   FaceDataset\s16\5.pgm  s16        s16  3.768868   True
# 36   FaceDataset\s16\6.pgm  s16        s16  6.684703   True
# 37   FaceDataset\s16\7.pgm  s16        s16  6.791978   True
# 38   FaceDataset\s16\8.pgm  s16        s16  7.471549   True
# 39   FaceDataset\s16\9.pgm  s16        s16  6.864977   True
# 40   FaceDataset\s17\5.pgm  s17        s17  3.391162   True
# 41   FaceDataset\s17\6.pgm  s17        s17  5.143400   True
# 42   FaceDataset\s17\7.pgm  s17        s17  3.970005   True
# 43   FaceDataset\s17\8.pgm  s17        s17  6.275889   True
# 44   FaceDataset\s17\9.pgm  s17        s17  4.800737   True
# 45   FaceDataset\s18\5.pgm  s18        s18  5.080505   True
# 46   FaceDataset\s18\6.pgm  s18        s18  4.690880   True
# 47   FaceDataset\s18\7.pgm  s18        s18  5.373593   True
# 48   FaceDataset\s18\8.pgm  s18        s18  3.784725   True
# 49   FaceDataset\s18\9.pgm  s18        s18  4.921170   True
# 50   FaceDataset\s19\5.pgm  s19        s19  2.284365   True
# 51   FaceDataset\s19\6.pgm  s19        s19  5.357866   True
# 52   FaceDataset\s19\7.pgm  s19        s19  5.273352   True
# 53   FaceDataset\s19\8.pgm  s19        s19  5.695330   True
# 54   FaceDataset\s19\9.pgm  s19        s36  7.106700  False
# 55    FaceDataset\s2\5.pgm   s2         s2  4.864419   True
# 56    FaceDataset\s2\6.pgm   s2         s2  4.584782   True
# 57    FaceDataset\s2\7.pgm   s2         s2  3.834803   True
# 58    FaceDataset\s2\8.pgm   s2         s2  3.095061   True
# 59    FaceDataset\s2\9.pgm   s2         s2  5.147697   True
# 60   FaceDataset\s20\5.pgm  s20         s3  7.382501  False
# 61   FaceDataset\s20\6.pgm  s20        s20  2.873756   True
# 62   FaceDataset\s20\7.pgm  s20        s20  7.219822   True
# 63   FaceDataset\s20\8.pgm  s20        s38  7.454174  False
# 64   FaceDataset\s20\9.pgm  s20        s23  7.441281  False
# 65   FaceDataset\s21\5.pgm  s21        s21  3.554686   True
# 66   FaceDataset\s21\6.pgm  s21        s21  4.940393   True
# 67   FaceDataset\s21\7.pgm  s21        s21  4.397489   True
# 68   FaceDataset\s21\8.pgm  s21        s21  3.679750   True
# 69   FaceDataset\s21\9.pgm  s21        s21  3.864153   True
# 70   FaceDataset\s22\5.pgm  s22        s22  3.743217   True
# 71   FaceDataset\s22\6.pgm  s22        s22  4.933434   True
# 72   FaceDataset\s22\7.pgm  s22        s22  3.856581   True
# 73   FaceDataset\s22\8.pgm  s22        s22  3.762515   True
# 74   FaceDataset\s22\9.pgm  s22        s22  3.419555   True
# 75   FaceDataset\s23\5.pgm  s23        s23  3.304435   True
# 76   FaceDataset\s23\6.pgm  s23        s23  2.333915   True
# 77   FaceDataset\s23\7.pgm  s23        s23  4.788510   True
# 78   FaceDataset\s23\8.pgm  s23        s23  2.550767   True
# 79   FaceDataset\s23\9.pgm  s23        s23  4.703488   True
# 80   FaceDataset\s24\5.pgm  s24        s24  5.511842   True
# 81   FaceDataset\s24\6.pgm  s24        s24  3.874343   True
# 82   FaceDataset\s24\7.pgm  s24        s24  3.792448   True
# 83   FaceDataset\s24\8.pgm  s24        s24  4.917153   True
# 84   FaceDataset\s24\9.pgm  s24        s24  4.081042   True
# 85   FaceDataset\s25\5.pgm  s25        s25  4.991458   True
# 86   FaceDataset\s25\6.pgm  s25        s25  3.863741   True
# 87   FaceDataset\s25\7.pgm  s25        s25  3.751255   True
# 88   FaceDataset\s25\8.pgm  s25        s25  5.635727   True
# 89   FaceDataset\s25\9.pgm  s25        s25  5.372662   True
# 90   FaceDataset\s26\5.pgm  s26        s26  4.782119   True
# 91   FaceDataset\s26\6.pgm  s26        s26  4.412911   True
# 92   FaceDataset\s26\7.pgm  s26        s26  6.294756   True
# 93   FaceDataset\s26\8.pgm  s26        s26  2.942327   True
# 94   FaceDataset\s26\9.pgm  s26        s26  5.618671   True
# 95   FaceDataset\s27\5.pgm  s27        s27  3.140452   True
# 96   FaceDataset\s27\6.pgm  s27        s16  6.968580  False
# 97   FaceDataset\s27\7.pgm  s27        s17  7.382531  False
# 98   FaceDataset\s27\8.pgm  s27        s27  6.549797   True
# 99   FaceDataset\s27\9.pgm  s27        s27  5.702230   True
# 100  FaceDataset\s28\5.pgm  s28        s28  4.000698   True
# 101  FaceDataset\s28\6.pgm  s28        s28  2.707916   True
# 102  FaceDataset\s28\7.pgm  s28        s28  5.615813   True
# 103  FaceDataset\s28\8.pgm  s28        s37  6.990444  False
# 104  FaceDataset\s28\9.pgm  s28        s28  6.804868   True
# 105  FaceDataset\s29\5.pgm  s29        s29  5.430209   True
# 106  FaceDataset\s29\6.pgm  s29        s29  5.795769   True
# 107  FaceDataset\s29\7.pgm  s29        s29  3.894009   True
# 108  FaceDataset\s29\8.pgm  s29        s29  5.843701   True
# 109  FaceDataset\s29\9.pgm  s29        s29  5.551328   True
# 110   FaceDataset\s3\5.pgm   s3         s3  5.178569   True
# 111   FaceDataset\s3\6.pgm   s3         s3  5.803057   True
# 112   FaceDataset\s3\7.pgm   s3         s3  6.071401   True
# 113   FaceDataset\s3\8.pgm   s3         s3  6.199107   True
# 114   FaceDataset\s3\9.pgm   s3         s3  3.607982   True
# 115  FaceDataset\s30\5.pgm  s30        s30  3.383501   True
# 116  FaceDataset\s30\6.pgm  s30        s30  3.914095   True
# 117  FaceDataset\s30\7.pgm  s30        s30  4.215257   True
# 118  FaceDataset\s30\8.pgm  s30        s30  3.839109   True
# 119  FaceDataset\s30\9.pgm  s30        s30  5.283624   True
# 120  FaceDataset\s31\5.pgm  s31        s31  3.828085   True
# 121  FaceDataset\s31\6.pgm  s31        s31  6.178684   True
# 122  FaceDataset\s31\7.pgm  s31        s31  6.264232   True
# 123  FaceDataset\s31\8.pgm  s31        s31  3.673105   True
# 124  FaceDataset\s31\9.pgm  s31        s31  5.024521   True
# 125  FaceDataset\s32\5.pgm  s32        s32  5.853003   True
# 126  FaceDataset\s32\6.pgm  s32        s32  4.404753   True
# 127  FaceDataset\s32\7.pgm  s32         s2  7.658939  False
# 128  FaceDataset\s32\8.pgm  s32        s32  6.208307   True
# 129  FaceDataset\s32\9.pgm  s32        s32  4.640069   True
# 130  FaceDataset\s33\5.pgm  s33        s33  5.708503   True
# 131  FaceDataset\s33\6.pgm  s33        s33  6.401813   True
# 132  FaceDataset\s33\7.pgm  s33        s33  5.235417   True
# 133  FaceDataset\s33\8.pgm  s33        s33  5.901632   True
# 134  FaceDataset\s33\9.pgm  s33        s33  5.310668   True
# 135  FaceDataset\s34\5.pgm  s34        s34  3.949253   True
# 136  FaceDataset\s34\6.pgm  s34        s34  4.062459   True
# 137  FaceDataset\s34\7.pgm  s34        s34  5.350774   True
# 138  FaceDataset\s34\8.pgm  s34        s34  3.048617   True
# 139  FaceDataset\s34\9.pgm  s34        s34  2.601446   True
# 140  FaceDataset\s35\5.pgm  s35        s35  5.966854   True
# 141  FaceDataset\s35\6.pgm  s35        s35  6.100732   True
# 142  FaceDataset\s35\7.pgm  s35        s35  7.283580   True
# 143  FaceDataset\s35\8.pgm  s35        s35  5.938974   True
# 144  FaceDataset\s35\9.pgm  s35        s35  7.965496   True
# 145  FaceDataset\s36\5.pgm  s36        s36  5.122988   True
# 146  FaceDataset\s36\6.pgm  s36        s36  6.563022   True
# 147  FaceDataset\s36\7.pgm  s36        s36  6.326369   True
# 148  FaceDataset\s36\8.pgm  s36        s36  4.017616   True
# 149  FaceDataset\s36\9.pgm  s36        s36  5.715619   True
# 150  FaceDataset\s37\5.pgm  s37        s37  3.827316   True
# 151  FaceDataset\s37\6.pgm  s37        s37  3.940036   True
# 152  FaceDataset\s37\7.pgm  s37        s37  5.218508   True
# 153  FaceDataset\s37\8.pgm  s37        s37  5.183556   True
# 154  FaceDataset\s37\9.pgm  s37        s37  2.977490   True
# 155  FaceDataset\s38\5.pgm  s38        s38  2.390676   True
# 156  FaceDataset\s38\6.pgm  s38        s38  3.649200   True
# 157  FaceDataset\s38\7.pgm  s38        s38  3.232082   True
# 158  FaceDataset\s38\8.pgm  s38        s38  5.357658   True
# 159  FaceDataset\s38\9.pgm  s38        s38  4.875450   True
# 160  FaceDataset\s39\5.pgm  s39        s22  6.627308  False
# 161  FaceDataset\s39\6.pgm  s39        s29  6.914198  False
# 162  FaceDataset\s39\7.pgm  s39        s39  5.920813   True
# 163  FaceDataset\s39\8.pgm  s39        s39  6.415657   True
# 164  FaceDataset\s39\9.pgm  s39        s21  6.739038  False
# 165   FaceDataset\s4\5.pgm   s4         s4  4.626727   True
# 166   FaceDataset\s4\6.pgm   s4         s4  6.170909   True
# 167   FaceDataset\s4\7.pgm   s4         s4  3.263477   True
# 168   FaceDataset\s4\8.pgm   s4         s4  3.037645   True
# 169   FaceDataset\s4\9.pgm   s4         s4  3.948956   True
# 170  FaceDataset\s40\5.pgm  s40         s5  4.905226  False
# 171  FaceDataset\s40\6.pgm  s40         s5  5.832241  False
# 172  FaceDataset\s40\7.pgm  s40         s5  6.204992  False
# 173  FaceDataset\s40\8.pgm  s40        s40  5.371745   True
# 174  FaceDataset\s40\9.pgm  s40         s5  6.028172  False
# 175   FaceDataset\s5\5.pgm   s5         s5  5.659868   True
# 176   FaceDataset\s5\6.pgm   s5         s5  5.062087   True
# 177   FaceDataset\s5\7.pgm   s5         s5  2.728970   True
# 178   FaceDataset\s5\8.pgm   s5         s5  6.324580   True
# 179   FaceDataset\s5\9.pgm   s5         s5  5.463125   True
# 180   FaceDataset\s6\5.pgm   s6         s6  4.044417   True
# 181   FaceDataset\s6\6.pgm   s6         s6  3.525420   True
# 182   FaceDataset\s6\7.pgm   s6         s6  4.105860   True
# 183   FaceDataset\s6\8.pgm   s6         s6  4.574489   True
# 184   FaceDataset\s6\9.pgm   s6         s6  5.442894   True
# 185   FaceDataset\s7\5.pgm   s7         s7  4.319325   True
# 186   FaceDataset\s7\6.pgm   s7         s7  4.763342   True
# 187   FaceDataset\s7\7.pgm   s7         s7  3.843917   True
# 188   FaceDataset\s7\8.pgm   s7         s7  5.892268   True
# 189   FaceDataset\s7\9.pgm   s7         s7  4.158843   True
# 190   FaceDataset\s8\5.pgm   s8         s8  4.987806   True
# 191   FaceDataset\s8\6.pgm   s8         s8  3.577018   True
# 192   FaceDataset\s8\7.pgm   s8         s8  4.566201   True
# 193   FaceDataset\s8\8.pgm   s8         s8  4.039599   True
# 194   FaceDataset\s8\9.pgm   s8         s8  5.761417   True
# 195   FaceDataset\s9\5.pgm   s9         s9  4.433079   True
# 196   FaceDataset\s9\6.pgm   s9         s9  5.851603   True
# 197   FaceDataset\s9\7.pgm   s9        s38  6.497577  False
# 198   FaceDataset\s9\8.pgm   s9         s9  4.592148   True
# 199   FaceDataset\s9\9.pgm   s9         s9  4.304052   True
